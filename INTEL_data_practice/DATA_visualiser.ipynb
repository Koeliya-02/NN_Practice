# %%
import os
os.listdir('/content/drive/MyDrive/INTEL_data_practice/DATA/seg_train/seg_train')
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
data_dist= {}
for sd in os.listdir('/content/drive/MyDrive/INTEL_data_practice/DATA/seg_train/seg_train'):
  #print(os.listdir(os.path.join('/content/drive/MyDrive/INTEL_data_practice/DATA/seg_train/seg_train', sd)))
  data_dist[sd] = len(os.listdir(os.path.join('/content/drive/MyDrive/INTEL_data_practice/DATA/seg_train/seg_train', sd)))
print(data_dist)
# Out:
# {'buildings': 1816, 'forest': 2271, 'glacier': 2404, 'mountain': 2029, 'sea': 1753, 'street': 3050}

# %%
import matplotlib.pyplot as plt

# Class names and counts
class_names = ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']
class_counts = [1816, 2271, 2404, 2029, 1753, 3050]

# Plotting the distribution
plt.figure(figsize=(10, 6))
plt.bar(class_names, class_counts, color='skyblue')
plt.xlabel('Class')
plt.ylabel('Number of Instances')
plt.title('Class Distribution in the Dataset')
plt.show()
